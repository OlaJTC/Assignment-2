# %% [markdown]
# <a href="https://colab.research.google.com/github/OlaJTC/Assignment-2/blob/main/Ola_Mohammad_GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment 2: Git and GitHub Version Control**

# %% [markdown]
# # This notebook demonstrates basic Git operations.

# %%
# !git --version
# Out:
# git version 2.43.0

# %%
# !git config --global user.name "OlaJTC"
# !git config --global user.email "jariryola@gmail.com"

# %% [markdown]
# ## **Clone Repository in Colab**

# %%
# !git clone https://github.com/OlaJTC/Assignment-2 .git
# Out:
# Cloning into '.git'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !ls Assignment-2
# Out:
# ls: cannot access 'Assignment-2': No such file or directory

# %% [markdown]
# # **Notebook Creation**

# %%
# %cd https://github.com/OlaJTC/Assignment-2 .git
# Out:
# [Errno 2] No such file or directory: 'https://github.com/OlaJTC/Assignment-2 .git'
# /content

# %% [markdown]
# # **Version Control Commands**

# %%
#Add & Commit

# !git Add Assignment_2.ipynb
# !git commit -m "Add initial notebook with multiplication function"
# Out:
# git: 'Add' is not a git command. See 'git --help'.
#
# The most similar command is
# 	add
# fatal: not a git repository (or any of the parent directories): .git

# %%
#Push to GitHub
# !git remote add origin https://github.com/OlaJTC/Assignment-2.git
# !git push origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# # **Branching and Updates**

# %%
#Create a New Branch
# !git chechout -b feature-branch
# Out:
# git: 'chechout' is not a git command. See 'git --help'.
#
# The most similar command is
# 	checkout

# %%
#Add New Function
def divide_numbers(a, b):
    if b != 0:
        return a / b
    else:
        return "Cannot divide by zero"

print(divide_numbers(10, 2))
# Out:
# 5.0

# %%
#Commit & Push
# !git add Assignment_2.ipynb
# !git commit -m "Add division function"
# !git push --set-upstream origin feature-branch
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
