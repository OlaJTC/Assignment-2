# %% [markdown]
# <a href="https://colab.research.google.com/github/OlaJTC/Assignment-2/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook Creation**

# %%
def multiply_numbers(a, b):
    return a * b

print(multiply_numbers(3, 4))
# Out:
# 12

# %%
# !git status.
# Out:
# git: 'status.' is not a git command. See 'git --help'.
#
# The most similar command is
# 	status
